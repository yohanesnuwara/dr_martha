# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)

# %%
# !cp -r '/kaggle/input/face-diagnosis/Eye Health 2.v1i.yolov8/train' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Eye Health 2.v1i.yolov8/valid' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Eye Health 2.v1i.yolov8/test' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Eye Health 2.v1i.yolov8/data.yaml' /kaggle/working

# %%
# %%writefile /kaggle/working/hyperparameter.yaml
# # 18/50 iterations complete ✅ (7656.93s)
# # Results saved to runs/detect/tune
# # Best fitness=0.25319 observed at iteration 3
# # Best fitness metrics are {'metrics/precision(B)': 0.18044, 'metrics/recall(B)': 0.52321, 'metrics/mAP50(B)': 0.35316, 'metrics/mAP50-95(B)': 0.24208, 'val/box_loss': 1.74616, 'val/cls_loss': 4.79955, 'val/dfl_loss': 2.4468, 'fitness': 0.25319}
# # Best fitness model is runs/detect/train3
# # Best fitness hyperparameters are printed below.
#
# lr0: 0.01023
# lrf: 0.00935
# momentum: 0.9307
# weight_decay: 0.00042
# warmup_epochs: 3.26568
# warmup_momentum: 0.94978
# box: 8.45218
# cls: 0.5
# dfl: 1.60249
# hsv_h: 0.01403
# hsv_s: 0.72222
# hsv_v: 0.40939
# degrees: 0.0
# translate: 0.1
# scale: 0.42409
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.49769
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
# Out:
# Writing /kaggle/working/hyperparameter.yaml

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('runs/detect/train/weights/best.pt')
# Out:
# /kaggle/working
# /kaggle/working/runs/detect/train/weights/best.pt

# %%
from ultralytics import YOLO
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 287MB/s]

# %%
# model.tune(data='/kaggle/working/data.yaml', epochs=50, iterations=50, optimizer='AdamW', plots=False, save=False, val=False)

# %%
results = model.train(data='/kaggle/working/data.yaml', epochs=200, imgsz=640,
                      cfg='/kaggle/working/hyperparameter.yaml')
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
