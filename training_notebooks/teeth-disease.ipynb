# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)

# %%
# !cp -r '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/train' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/valid' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/test' /kaggle/working/
# !cp -r '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/data.yaml' /kaggle/working
# Out:
# cp: cannot stat '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/train': No such file or directory
# cp: cannot stat '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/valid': No such file or directory
# cp: cannot stat '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/test': No such file or directory
# cp: cannot stat '/kaggle/input/face-diagnosis/Teeth Health.v1i.yolov8/data.yaml': No such file or directory

# %%
from ultralytics import YOLO
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 351MB/s]

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('runs/detect/train/weights/best.pt')
# Out:
# /kaggle/working
# /kaggle/working/runs/detect/train/weights/best.pt

# %%
results = model.train(data='/kaggle/working/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
